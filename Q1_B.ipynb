# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

url = "https://itc.gymkhana.iitb.ac.in/wncc/soc/"

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

project_urls = soup.find_all("div", class_="col-lg-4 col-6 mb-4 shuffle-item")
project_urls = ["https://itc.gymkhana.iitb.ac.in" +
                project_detail.find("a").get("href") for project_detail in project_urls]

project_names = soup.find_all(
    "p", class_="lead text-center font-weight-bold text-dark")
project_names = [project_name.text for project_name in project_names]

print(project_names)
print(project_urls)
# Out:
# ['TEXT SUMMARIZATION WEB APP', 'Competitive Programming', 'Write yourself a Git!', 'File Compression System', 'FAST-G', 'Developing Trading Strategy with Pine Script', 'Real time Driver Drowsiness detection System', 'The Image Cartoonifier', 'Speech to Speech Translation', 'Competitive Programming - Newbie to Master', 'Path-Planning of Swarm Robotics in 2/3D space', 'Image Super Resolution using Deep Neural Networks', 'Enhance Low Resolution Image using GANs', 'MyBox', 'Deep Carlsen', 'InstiExchange - A web marketplace for IITB', 'Homomorphic Encryption for k-NN on the Cloud', 'TRayCer', 'Social media website with MERN', 'Dive into Digital Image Processing', 'Neural Quest', 'To the Quantum Future', 'Street Fighter II - Reinforcement Learning', 'Combinatorial Computing', 'Navigating the Waters of AI', 'Autonomous Driving Vehicle', 'Author Identification through Stylometric Analysis', 'Breakout Genius - Using RL to Build an AI Game Master', 'Image Captioning', 'Cricbuzz', 'Competitive Programming (CP)', 'Economics meets Machine Learning', 'SynerG Lab, CSE Department - Webpage', 'Computer vision for driverless vehicles', 'AudioHive A Social Audio App', 'Learning the Latent structure in LLMs', 'EdConnect', 'NFTs Where Art and Tech Converge', 'Dive into the World of Quant', 'COLLIDE', 'Image Processing and Object Detection', 'Unreal IITB', 'Human Pose Estimation', 'Find me out', 'Sign Language Recogniser', 'E-Commerce Website for VibSpecLab, IIT Bombay', 'Image Caption Generator', 'Intro Full stack web development:Restaurant website', 'App for Credit rating of Retailers in Clothing Industry', 'Ray Tracing', 'YOLO-Cam-Object Detection based Analytics', 'Physically Based Rendering', 'A Secure Erasure Code-Based Cloud Storage System with Secure Data Forwarding', 'Graph Machine Learning', '“The Watchdogs” - Solving a murder mystery using Computer Vision and Data Science', 'ArgueAI', 'Comic GPT', 'InstiNav', 'Face detection for attendance using AI', 'Hands on Reinforcement', 'RegExamaton', 'Institute OnChain Voting System with ZKPs', 'Using Deep RL and NLP to allocate stocks in portfolio', "Blockchain Development- It's not that difficult!", 'Light field imaging and Dual Attention Networks', 'Stable Diffusion', 'FlappeRL', 'Hands-on Computational Physics', 'Image Colorization', 'PaperPal', 'JobFinderX']
# ['https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project221.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project292.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/item223.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project224.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project225.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project226.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project227.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project228.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project229.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project230.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project241.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project242.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project243.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project244.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project245.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project246.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project247.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project248.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project254.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project249.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project250.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project251.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project252.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project253.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project255.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project256.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project257.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project258.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project259.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project260.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project261.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project262.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project263.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project264.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project265.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project266.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project267.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project268.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project269.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project270.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project271.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project272.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project273.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project274.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project275.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project276.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project277.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project278.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project279.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project280.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project281.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project282.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project283.html', 'https://itc.gymkhana.iitb.ac.in/wncc/soc/projects/2023/project284.html', 'https ...

# %%
project_info = {}

print(len(project_names))

for i in range(len(project_names)):
    project_info[project_names[i]] = {}
    project_info[project_names[i]]["project_url"] = project_urls[i]
    response = requests.get(project_urls[i])
    soup = BeautifulSoup(response.content, "html.parser")
    project_info[project_names[i]]["mentors"] = [mentor.text for mentor in soup.find(
        "h4", class_="display3").find_next_sibling("ul").find_all("li")]
    
    timeline = soup.find("table", class_="table-striped")
    weeks = []
    work = []

    for row in timeline.find_all("tr"):
        if row.find_all("td") == []:
            continue
        weeks.append(row.find_all("td")[0].text)
        work.append(row.find_all("td")[1].text)

    df = pd.DataFrame({"Week": weeks, "Work": work})

    project_info[project_names[i]]["timeline"] = df.to_dict("records")
    project_info[project_names[i]]["prerequisites"] = re.search(r"Prerequisites:\s*(.*?)<", str(soup), re.I)
    if project_info[project_names[i]]["prerequisites"] != None:
        project_info[project_names[i]]["prerequisites"] = project_info[project_names[i]]["prerequisites"].group(1)
    else:
        project_info[project_names[i]]["prerequisites"] = "N/A"
    

project_info_df = pd.DataFrame(project_info)

print(project_info_df)
# Out:
# 71
#                                       TEXT SUMMARIZATION WEB APP  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors              [kundeshwar vijay pundalik, ADRESH ALAGADE]
# timeline       [{'Week': 'Week 1-3', 'Work': 'EDA and Some ot...
# prerequisites  BASIC PYTHON , (HTML OR STREAMLIT) , BASIC KNO...
#
#                                          Competitive Programming  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                                         [Virendra Kabra]
# timeline       [{'Week': 'Week 1', 'Work': 'C++ STL Basics'},...
# prerequisites                                                N/A
#
#                                            Write yourself a Git!  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                                  [Abhijeet Prasad Bodas]
# timeline       [{'Week': 'Week 1', 'Work': 'Install a GNU/Lin...
# prerequisites                                                N/A
#
#                                          File Compression System  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                                      [Amritaansh Narain]
# timeline       [{'Week': 'Week 1&2', 'Work': 'Basic overview ...
# prerequisites  Assume you have basic understanding of C++ and...
#
#                                                           FAST-G  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors        [Ameya Vikram Singh, Prerak Contractor, Anish ...
# timeline       [{'Week': 'Week 1', 'Work': 'Basics of graphs ...
# prerequisites                                                N/A
#
#                     Developing Trading Strategy with Pine Script  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                               [Vivek Kumar, Rajik Kumar]
# timeline       [{'Week': 'Week 1-3', 'Work': 'Introduction to...
# prerequisites                                                N/A
#
#                     Real time Driver Drowsiness detection System  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                                            [Vedang Bale]
# timeline       [{'Week': 'Week 1', 'Work': 'Python Programmin...
# prerequisites                                                N/A
#
#                                           The Image Cartoonifier  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors               [Jaideep Chandra, Sridhar, Bhavani Sankar]
# timeline       [{'Week': 'Week 1', 'Work': 'Introduction to P...
# prerequisites                                                N/A
#
#                                     Speech to Speech Translation  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                                       [Swapnoneel Kayal]
# timeline       [{'Week': 'Week 1', 'Work': 'Brush up on / Pyt...
# prerequisites                                                N/A
#
#                       Competitive Programming - Newbie to Master  ...  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...  ...
# mentors                          [Parth Dwivedi, Kunal Kundwani]  ...
# timeline       [{'Week': 'Week 1', 'Work': 'Start out with ba...  ...
# prerequisites                                                N/A  ...
#
#                        Institute OnChain Voting System with ZKPs  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors           [Nikhil Tiwari, Ananya Khandelwal, Ishit Garg]
# timeline       [{'Week': 'Week 1', 'Work': 'Gain basic knowle...
# prerequisites                                                N/A
#
#               Using Deep RL and NLP to allocate stocks in portfolio  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                  [Nikhil Tiwari, Ishan Jain (200100073)]
# timeline       [{'Week': 'Week 1', 'Work': 'Read basics of de...
# prerequisites                                                N/A
#
#                 Blockchain Development- It's not that difficult!  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors        [Pragyesh Gupta, Dhruvkumar Patil (200100056),...
# timeline       [{'Week': 'Week 1', 'Work': ' Introduction to ...
# prerequisites                                                N/A
#
#                  Light field imaging and Dual Attention Networks  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                [Abeer Mishra, Shreyas Patil (200260052)]
# timeline       [{'Week': 'Week 1-2', 'Work': ' Basics of Mach...
# prerequisites                                                N/A
#
#                                                 Stable Diffusion  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors        [Shubham Hazra, Om Godage (21d100006), Kartik ...
# timeline       [{'Week': 'Week 1', 'Work': 'Basics of Regress...
# prerequisites                                                N/A
#
#                                                         FlappeRL  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                           [Kartik Gokhale, Hastyn Doshi]
# timeline       [{'Week': 'Week 1', 'Work': 'Catching up on Py...
# prerequisites                                                N/A
#
#                                   Hands-on Computational Physics  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors          [Kaustav Prasada, Varad Mahashabde (200260057)]
# timeline       [{'Week': 'Week 1-2', 'Work': '- Introduction ...
# prerequisites                                                N/A
#
#                                               Image Colorization  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                                          [Valay Bundele]
# timeline       [{'Week': 'Week 1-2', 'Work': 'Read about the ...
# prerequisites                                                N/A
#
#                                                         PaperPal  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors            [Vishruth N, Abhinav Raghuvanshi (200040008)]
# timeline       [{'Week': 'Week 1', 'Work': 'Set up project re...
# prerequisites                                                N/A
#
#                                                       JobFinderX
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors        [Baggam Rakshan Tej (210070019), Pamba Ravindr...
# timeline       [{'Week': 'Week 1', 'Work': 'HTML, CSS'}, {'We...
# prerequisites                                                N/A
#
# [4 rows x 71 columns]

# %%
# Validate and clean data
for name, info in project_info.items():
    if "timeline" in info:
        for i, week_info in enumerate(info["timeline"]):
            if "week" not in week_info:
                print(f"Missing week information for project {name}, timeline entry {i}. Setting week to 0.")
                week_info["week"] = 0
            if "description" not in week_info:
                print(f"Missing description for project {name}, timeline entry {i}. Setting description to ''.")
                week_info["description"] = ""
            elif not isinstance(week_info["week"], int):
                print(f"Invalid week value for project {name}, timeline entry {i}. Converting to int.")
                week_info["week"] = int(week_info["week"])
            week_info["description"] = week_info["description"].strip()
    else:
        print(f"Missing timeline information for project {name}. Adding empty timeline.")
        project_info[name]["timeline"] = []

project_info_df = pd.DataFrame(project_info)
# Out:
# Missing week information for project TEXT SUMMARIZATION WEB APP, timeline entry 0. Setting week to 0.
# Missing description for project TEXT SUMMARIZATION WEB APP, timeline entry 0. Setting description to ''.
# Missing week information for project TEXT SUMMARIZATION WEB APP, timeline entry 1. Setting week to 0.
# Missing description for project TEXT SUMMARIZATION WEB APP, timeline entry 1. Setting description to ''.
# Missing week information for project TEXT SUMMARIZATION WEB APP, timeline entry 2. Setting week to 0.
# Missing description for project TEXT SUMMARIZATION WEB APP, timeline entry 2. Setting description to ''.
# Missing week information for project TEXT SUMMARIZATION WEB APP, timeline entry 3. Setting week to 0.
# Missing description for project TEXT SUMMARIZATION WEB APP, timeline entry 3. Setting description to ''.
# Missing week information for project Competitive Programming, timeline entry 0. Setting week to 0.
# Missing description for project Competitive Programming, timeline entry 0. Setting description to ''.
# Missing week information for project Competitive Programming, timeline entry 1. Setting week to 0.
# Missing description for project Competitive Programming, timeline entry 1. Setting description to ''.
# Missing week information for project Competitive Programming, timeline entry 2. Setting week to 0.
# Missing description for project Competitive Programming, timeline entry 2. Setting description to ''.
# Missing week information for project Competitive Programming, timeline entry 3. Setting week to 0.
# Missing description for project Competitive Programming, timeline entry 3. Setting description to ''.
# Missing week information for project Competitive Programming, timeline entry 4. Setting week to 0.
# Missing description for project Competitive Programming, timeline entry 4. Setting description to ''.
# Missing week information for project Competitive Programming, timeline entry 5. Setting week to 0.
# Missing description for project Competitive Programming, timeline entry 5. Setting description to ''.
# Missing week information for project Competitive Programming, timeline entry 6. Setting week to 0.
# Missing description for project Competitive Programming, timeline entry 6. Setting description to ''.
# Missing week information for project Competitive Programming, timeline entry 7. Setting week to 0.
# Missing description for project Competitive Programming, timeline entry 7. Setting description to ''.
# Missing week information for project Write yourself a Git!, timeline entry 0. Setting week to 0.
# Missing description for project Write yourself a Git!, timeline entry 0. Setting description to ''.
# Missing week information for project Write yourself a Git!, timeline entry 1. Setting week to 0.
# Missing description for project Write yourself a Git!, timeline entry 1. Setting description to ''.
# Missing week information for project Write yourself a Git!, timeline entry 2. Setting week to 0.
# Missing description for project Write yourself a Git!, timeline entry 2. Setting description to ''.
# Missing week information for project Write yourself a Git!, timeline entry 3. Setting week to 0.
# Missing description for project Write yourself a Git!, timeline entry 3. Setting description to ''.
# Missing week information for project Write yourself a Git!, timeline entry 4. Setting week to 0.
# Missing description for project Write yourself a Git!, timeline entry 4. Setting description to ''.
# Missing week information for project Write yourself a Git!, timeline entry 5. Setting week to 0.
# Missing description for project Write yourself a Git!, timeline entry 5. Setting description to ''.
# Missing week information for project Write yourself a Git!, timeline entry 6. Setting week to 0.
# Missing description for project Write yourself a Git!, timeline entry 6. Setting description to ''.
# Missing week information for project Write yourself a Git!, timeline entry 7. Setting week to 0.
# Missing description for project Write yourself a Git!, timeline entry 7. Setting description to ''.
# Missing week information for project File Compression System, timeline entry 0. Setting week to 0.
# Missing description for project File Compression System, timeline entry 0. Setting description to ''.
# Missing week information for project File Compression System, timeline entry 1. Setting week to 0.
# Missing description for project File Compression System, timeline entry 1. Setting description to ''.
# Missing week information for project File Compression System, timeline entry 2. Setting week to 0.
# Missing description for project File Compression System, timeline entry 2. Setting description to ''.
# Missing week information for project File Compression System, timeline entry 3. Setting week to 0.
# Missing description for project File Compression System, timeline entry 3. Setting description to ''.
# Missing week information for project File Compression System, timeline entry 4. Setting week to 0.
# Missing description for project File Compression System, timeline entry 4. Setting description to ''.
# Missing week information for project File Compression System, timeline entry 5. Setting week to 0.
# Missing description for project File Compression System, timeline entry 5. Setting description to ''.
# Missing week information for project File Compression System, timeline entry 6. Setting week to 0.
# Missing description for project File Compression System, timeline entry 6. Setting description to ''.
# Missing week information for project FAST-G, timeline entry 0. Setting week to 0.
# Missing description for project FAST-G, timeline entry 0. Setting description to ''.
# Missing week information for project FAST-G, timeline entry 1. Setting week to 0.
# Missing description for project FAST-G, timeline entry 1. Setting description to ''.
# Missing week information for project FAST-G, timeline entry 2. Setting week to 0.
# Missing description for project FAST-G, timeline entry 2. Setting description to ''.
# Missing week information for project FAST-G, timeline entry 3. Setting week to 0.
# Missing description for project FAST-G, timeline entry 3. Setting description to ''.
# Missing week information for project FAST-G, timeline entry 4. Setting week to 0.
# Missing description for project FAST-G, timeline entry 4. Setting description to ''.
# Missing week information for project FAST-G, timeline entry 5. Setting week to 0.
# Missing description for project FAST-G, timeline entry 5. Setting description to ''.
# Missing week information for project FAST-G, timeline entry 6. Setting week to 0.
# Missing description for project FAST-G, timeline entry 6. Setting description to ''.
# Missing week information for project FAST-G, timeline entry 7. Setting week to 0.
# Missing description for project FAST-G, timeline entry 7. Setting description to ''.
# Missing week information for project Developing Trading Strategy with Pine Script, timeline entry 0. Setting week to 0.
# Missing description for project Developing Trading Strategy with Pine Script, timeline entry 0. Setting description to ''.
# Missing week information for project Developing Trading Strategy with Pine Script, timeline entry 1. Setting week to 0.
# Missing description for project Developing Trading Strategy with Pine Script, timeline entry 1. Setting description to ''.
# Missing week information for project Developing Trading Strategy with Pine Script, timeline entry 2. Setting week to 0.
# Missing description for project Developing Trading Strategy with Pine Script, timeline entry 2. Setting description to ''.
# Missing week information for project Developing Trading Strategy with Pine Script, timeline entry 3. Setting week to 0.
# Missing description for project Developing Trading Strategy with Pine Script, timeline entry 3. Setting description to ''.
# Missing week information for project Real time Driver Drowsiness detection System, timeline entry 0. Setting week to 0.
# Missing description for project Real time Driver Drowsiness detection System, timeline entry 0. Setting description to ''.
# Missing week information for project Real time Driver Drowsiness detection System, timeline entry 1. Setting week to 0.
# Missing description for project Real time Driver Drowsiness detection System, timeline entry 1. Setting description to ''.
# Missing week information for project Real time Driver Drowsiness detection System, timeline entry 2. Setting week to 0.
# Missing description for project Real time Driver Drowsiness detection System, timeline entry 2. Setting description to ''.
# Missing week information for project Real time Driver Drowsiness detection System, timeline entry 3. Setting week to 0.
# Missing description for project Real time Driver Drowsiness detection System, timeline entry 3. Setting description to ''.
# Missing week information for project Real time Driver Drowsiness detection System, timeline entry 4. Setting week to 0.
# Missing description for project Real time Driver Drowsiness detection System, timeline entry 4. Setting description to ''.
# Missing week information for project The Image Cartoonifier, timeline entry 0. Setting week to 0.
# Missing description for project The Image Cartoonifier, timeline entry 0. Setting description to ''.
# Missing week information for project The Image Cartoonifier, timeline entry 1. Setting week to 0.
# Missing description for project The Image Cartoonifier, timeline entry 1. Setting description to ''.
# Missing week information for project The Image Cartoonifier, timeline entry 2. Setting week to 0.
# Missing description for project The Image Cartoonifier, timeline entry 2. Setting description to ''.
# Missing week information for project The Image Cartoonifier, timeline entry 3. Setting week to 0.
# Missing description for project The Image Cartoonifier, timeline entry 3. Setting description to ''.
# Missing week information for project The Image Cartoonifier, timeline entry 4. Setting week to 0.
# Missing description for project The Image Cartoonifier, timeline entry 4. Setting description to ''.
# Missing week information for project Speech to Speech Translation, timeline entry 0. Setting week to 0.
# Missing description for project Speech to Speech Translation, timeline entry 0. Setting description to ''.
# Missing week information for project Speech to Speech Translation, timeline entry 1. Setting week to 0.
# Missing description for project Speech to Speech Translation, timeline entry 1. Setting description to ''.
# Missing week information for project Speech to Speech Translation, timeline entry 2. Setting week to 0.
# Missing description for project Speech to Speech Translation, timeline entry 2. Setting description to ''.
# Missing week information for project Speech to Speech Translation, timeline entry 3. Setting week to 0.
# Missing description for project Speech to Speech Translation, timeline entry 3. Setting description to ''.
# Missing week information for project Speech to Speech Translation, timeline entry 4. Setting week to 0.
# Missing description for project Speech to Speech Translation, timeline entry 4. Setting description to ''.
# Missing week information for project Speech to Speech Translation, timeline entry 5. Setting week to 0.
# Missing description for project Speech to Speech Translation, timeline entry 5. Setting description to ''.
# Missing week information for project Speech to Speech Translation, timeline entry 6. Setting week to 0.
# Missing description for project Speech to Speech Translation, timeline entry 6. Setting description to ''.
# Missing week information for project Speech to Speech Translation, timeline entry 7. Setting week to 0.
# Missing description for project Speech to Speech Translation, timeline entry 7. Setting description to ''.
# Missing week information for project Competitive Programming - Newbie to Master, timeline entry 0. Setting week to 0.
# Missing description for project Competitive Programming - Newbie to Master, timeline entry 0. Setting description to ''.
# Missing week information for project Competitive Programming - Newbie to Master, timeline entry 1. Setting week to 0.
# Missing description for project Competitive Programming - Newbie to Master, timeline entry 1. Setting description to ''.
# Missing week information for project Competitive Programming - Newbie to Master, timeline entry 2. Setting week to 0.
# Missing description for project Competitive Programming - Newbie to Master, timeline entry 2. Setting description to ''.
# Missing week information for project Competitive Programming - Newbie to Master, timeline entry 3. Setting week to 0.
# Missing description for project Competitive Programming - Newbie to Master, timeline entry 3. Setting description to ''.
# Missing week information for project Competitive Programming - Newbie to Master, timeline entry 4. Setting week to 0.
# Missing description for project Competitive Programming - Newbie to Master, timeline entry 4. Setting description to ''.
# Missing week information for project Competitive Programming - Newbie to Master, timeline entry 5. Setting week to 0.
# Missing description for project Competitive Programming - Newbie to Master, timeline entry 5. Setting description to ''.
# Missing week information for project Competitive Programming - Newbie to Master, timeline entry 6. Setting week to 0.
# Missing description for project Competitive Programming - Newbie to Master, timeline entry 6. Setting description to ''.
# Missing week information for project Competitive Programming - Newbie to Master, timeline entry 7. Setting week to 0.
# Missing description for project Competitive Programming - Newbie to Master, timeline entry 7. Setting description to ''.
# Missing week information for project Path-Planning of Swarm Robotics in 2/3D space, timeline entry 0. Setting week to 0.
# Missing description for project Path-Planning of Swarm Robotics in 2/3D space, timeline entry 0. Setting description to ''.
# Missing week information for project Path-Planning of Swarm Robotics in 2/3D space, timeline entry 1. Setting week to 0.
# Missing description for project Path-Planning of Swarm Robotics in 2/3D space, timeline entry 1. Setting description to ''.
# Missing week information for project Path-Planning of Swarm Robotics in 2/3D space, timeline entry 2. Setting week to 0.
# Missing description for project Path-Planning of Swarm Robotics in 2/3D space, timeline entry 2. Setting description to ''.
# Missing week information for project Path-Planning of Swarm Robotics in 2/3D space, timeline entry 3. Setting week to 0.
# Missing description for project Path-Planning of Swarm Robotics in 2/3D space, timeline entry 3. Setting description to ''.
# Missing week information for project Path-Planning of Swarm Robotics in 2/3D space, timeline entry 4. Setting week to 0.
# Missing description for project Path-Planning of Swarm Robotics in 2/3D space, timeline entry 4. Setting description to ''.
# Missing week information for project Image Super Resolution using Deep Neural Networks, timeline entry 0. Setting week to 0.
# Missing description for project Image Super Resolution using Deep Neural Networks, timeline entry 0. Setting description to ''.
# Missing week information for project Image Super Resolution using Deep Neural Networks, timeline entry 1. Setting week to 0.
# Missing description for project Image Super Resolution using Deep Neural Networks, timeline entry 1. Setting description to ''.
# Missing week information for project Image Super Resolution using Deep Neural Networks, timeline entry 2. Setting week to 0.
# Missing description for project Image Super Resolution using Deep Neural Networks, timeline entry 2. Setting description to ''.
# Missing week information for project Image Super Resolution using Deep Neural Networks, timeline entry 3. Setting week to 0.
# Missing description for project Image Super Resolution using Deep Neural Networks, timeline entry 3. Setting description to ''.
# Missing week information for project Image Super Resolution using Deep Neural Networks, timeline entry 4. Setting week to 0.
# Missing description for project Image Super Resolution using Deep Neural Networks, timeline entry 4. Setting description to ''.
# Missing week information for project Image Super Resolution using Deep Neural Networks, timeline entry 5. Setting week to 0.
# Missing description for project Image Super Resolution using Deep Neural Networks, timeline entry 5. Setting description to ''.
# Missing week information for project Enhance Low Resolution Image using GANs, timeline entry 0. Setting week to 0.
# Missing description for project Enhance Low Resolution Image using GANs, timeline entry 0. Setting description to ''.
# Missing week information for project Enhance Low Resolution Image using GANs, timeline entry 1. Setting week to 0.
# Missing description for project Enhance Low Resolution Image using GANs, timeline entry 1. Setting description to ''.
# Missing week information for project Enhance Low Resolution Image using GANs, timeline entry 2. Setting week to 0.
# Missing description for project Enhance Low Resolution Image using GANs, timeline entry 2. Setting description to ''.
# Missing week information for project Enhance Low Resolution Image using GANs, timeline entry 3. Setting week to 0.
# Missing description for project Enhance Low Resolution Image using GANs, timeline entry 3. Setting description to ''.
# Missing week information for project Enhance Low Resolution Image using GANs, timeline entry 4. Setting week to 0.
# Missing description for project Enhance Low Resolution Image using GANs, timeline entry 4. Setting description to ''.
# Missing week information for project Enhance Low Resolution Image using GANs, timeline entry 5. Setting week to 0.
# Missing description for project Enhance Low Resolution Image using GANs, timeline entry 5. Setting description to ''.
# Missing week information for project Enhance Low Resolution Image using GANs, timeline entry 6. Setting week to 0.
# Missing description for project Enhance Low Resolution Image using GANs, timeline entry 6. Setting description to ''.
# Missing week information for project Enhance Low Resolution Image using GANs, timeline entry 7. Setting week to 0.
# Missing description for project Enhance Low Resolution Image using GANs, timeline entry 7. Setting description to ''.
# Missing week information for project MyBox, timeline entry 0. Setting week to 0.
# Missing description for project MyBox, timeline entry 0. Setting description to ''.
# Missing week information for project MyBox, timeline entry 1. Setting week to 0.
# Missing description for project MyBox, timeline entry 1. Setting description to ''.
# Missing week information for project MyBox, timeline entry 2. Setting week to 0.
# Missing description for project MyBox, timeline entry 2. Setting description to ''.
# Missing week information for project MyBox, timeline entry 3. Setting week to 0.
# Missing description for project MyBox, timeline entry 3. Setting description to ''.
# Missing week information for project MyBox, timeline entry 4. Setting week to 0.
# Missing description for project MyBox, timeline entry 4. Setting description to ''.
# Missing week information for project MyBox, timeline entry 5. Setting week to 0.
# Missing description for project MyBox, timeline entry 5. Setting description to ''.
# Missing week information for project MyBox, timeline entry 6. Setting week to 0.
# Missing description for project MyBox, timeline entry 6. Setting description to ''.
# Missing week information for project Deep Carlsen, timeline entry 0. Setting week to 0.
# Missing description for project Deep Carlsen, timeline entry 0. Setting description to ''.
# Missing week information for project Deep Carlsen, timeline entry 1. Setting week to 0.
# Missing description for project Deep Carlsen, timeline entry 1. Setting description to ''.
# Missing week information for project Deep Carlsen, timeline entry 2. Setting week to 0.
# Missing description for project Deep Carlsen, timeline entry 2. Setting description to ''.
# Missing week information for project Deep Carlsen, timeline entry 3. Setting week to 0.
# Missing description for project Deep Carlsen, timeline entry 3. Setting description to ''.
# Missing week information for project Deep Carlsen, timeline entry 4. Setting week to 0.
# Missing description for project Deep Carlsen, timeline entry 4. Setting description to ''.
# Missing week information for project Deep Carlsen, timeline entry 5. Setting week to 0.
# Missing description for project Deep Carlsen, timeline entry 5. Setting description to ''.
# Missing week information for project InstiExchange - A web marketplace for IITB, timeline entry 0. Setting week to 0.
# Missing description for project InstiExchange - A web marketplace for IITB, timeline entry 0. Setting description to ''.
# Missing week information for project InstiExchange - A web marketplace for IITB, timeline entry 1. Setting week to 0.
# Missing description for project InstiExchange - A web marketplace for IITB, timeline entry 1. Setting description to ''.
# Missing week information for project InstiExchange - A web marketplace for IITB, timeline entry 2. Setting week to 0.
# Missing description for project InstiExchange - A web marketplace for IITB, timeline entry 2. Setting description to ''.
# Missing week information for project InstiExchange - A web marketplace for IITB, timeline entry 3. Setting week to 0.
# Missing description for project InstiExchange - A web marketplace for IITB, timeline entry 3. Setting description to ''.
# Missing week information for project InstiExchange - A web marketplace for IITB, timeline entry 4. Setting week to 0.
# Missing description for project InstiExchange - A web marketplace for IITB, timeline entry 4. Setting description to ''.
# Missing week information for project InstiExchange - A web marketplace for IITB, timeline entry 5. Setting week to 0.
# Missing description for project InstiExchange - A web marketplace for IITB, timeline entry 5. Setting description to ''.
# Missing week information for project InstiExchange - A web marketplace for IITB, timeline entry 6. Setting week to 0.
# Missing description for project InstiExchange - A web marketplace for IITB, timeline entry 6. Setting description to ''.
# Missing week information for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 0. Setting week to 0.
# Missing description for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 0. Setting description to ''.
# Missing week information for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 1. Setting week to 0.
# Missing description for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 1. Setting description to ''.
# Missing week information for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 2. Setting week to 0.
# Missing description for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 2. Setting description to ''.
# Missing week information for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 3. Setting week to 0.
# Missing description for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 3. Setting description to ''.
# Missing week information for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 4. Setting week to 0.
# Missing description for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 4. Setting description to ''.
# Missing week information for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 5. Setting week to 0.
# Missing description for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 5. Setting description to ''.
# Missing week information for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 6. Setting week to 0.
# Missing description for project Homomorphic Encryption for k-NN on the Cloud, timeline entry 6. Setting description to ''.
# Missing week information for project TRayCer, timeline entry 0. Setting week to 0.
# Missing description for project TRayCer, timeline entry 0. Setting description to ''.
# Missing week information for project TRayCer, timeline entry 1. Setting week to 0.
# Missing description for project TRayCer, timeline entry 1. Setting description to ''.
# Missing week information for project TRayCer, timeline entry 2. Setting week to 0.
# Missing description for project TRayCer, timeline entry 2. Setting description to ''.
# Missing week information for project TRayCer, timeline entry 3. Setting week to 0.
# Missing description for project TRayCer, timeline entry 3. Setting description to ''.
# Missing week information for project TRayCer, timeline entry 4. Setting week to 0.
# Missing description for project TRayCer, timeline entry 4. Setting description to ''.
# Missing week information for project TRayCer, timeline entry 5. Setting week to 0.
# Missing description for project TRayCer, timeline entry 5. Setting description to ''.
# Missing week information for project Social media website with MERN, timeline entry 0. Setting week to 0.
# Missing description for project Social media website with MERN, timeline entry 0. Setting description to ''.
# Missing week information for project Social media website with MERN, timeline entry 1. Setting week to 0.
# Missing description for project Social media website with MERN, timeline entry 1. Setting description to ''.
# Missing week information for project Social media website with MERN, timeline entry 2. Setting week to 0.
# Missing description for project Social media website with MERN, timeline entry 2. Setting description to ''.
# Missing week information for project Social media website with MERN, timeline entry 3. Setting week to 0.
# Missing description for project Social media website with MERN, timeline entry 3. Setting description to ''.
# Missing week information for project Social media website with MERN, timeline entry 4. Setting week to 0.
# Missing description for project Social media website with MERN, timeline entry 4. Setting description to ''.
# Missing week information for project Social media website with MERN, timeline entry 5. Setting week to 0.
# Missing description for project Social media website with MERN, timeline entry 5. Setting description to ''.
# Missing week information for project Social media website with MERN, timeline entry 6. Setting week to 0.
# Missing description for project Social media website with MERN, timeline entry 6. Setting description to ''.
# Missing week information for project Dive into Digital Image Processing, timeline entry 0. Setting week to 0.
# Missing description for project Dive into Digital Image Processing, timeline entry 0. Setting description to ''.
# Missing week information for project Dive into Digital Image Processing, timeline entry 1. Setting week to 0.
# Missing description for project Dive into Digital Image Processing, timeline entry 1. Setting description to ''.
# Missing week information for project Dive into Digital Image Processing, timeline entry 2. Setting week to 0.
# Missing description for project Dive into Digital Image Processing, timeline entry 2. Setting description to ''.
# Missing week information for project Dive into Digital Image Processing, timeline entry 3. Setting week to 0.
# Missing description for project Dive into Digital Image Processing, timeline entry 3. Setting description to ''.
# Missing week information for project Dive into Digital Image Processing, timeline entry 4. Setting week to 0.
# Missing description for project Dive into Digital Image Processing, timeline entry 4. Setting description to ''.
# Missing week information for project Neural Quest, timeline entry 0. Setting week to 0.
# Missing description for project Neural Quest, timeline entry 0. Setting description to ''.
# Missing week information for project Neural Quest, timeline entry 1. Setting week to 0.
# Missing description for project Neural Quest, timeline entry 1. Setting description to ''.
# Missing week information for project Neural Quest, timeline entry 2. Setting week to 0.
# Missing description for project Neural Quest, timeline entry 2. Setting description to ''.
# Missing week information for project Neural Quest, timeline entry 3. Setting week to 0.
# Missing description for project Neural Quest, timeline entry 3. Setting description to ''.
# Missing week information for project Neural Quest, timeline entry 4. Setting week to 0.
# Missing description for project Neural Quest, timeline entry 4. Setting description to ''.
# Missing week information for project Neural Quest, timeline entry 5. Setting week to 0.
# Missing description for project Neural Quest, timeline entry 5. Setting description to ''.
# Missing week information for project To the Quantum Future, timeline entry 0. Setting week to 0.
# Missing description for project To the Quantum Future, timeline entry 0. Setting description to ''.
# Missing week information for project To the Quantum Future, timeline entry 1. Setting week to 0.
# Missing description for project To the Quantum Future, timeline entry 1. Setting description to ''.
# Missing week information for project To the Quantum Future, timeline entry 2. Setting week to 0.
# Missing description for project To the Quantum Future, timeline entry 2. Setting description to ''.
# Missing week information for project To the Quantum Future, timeline entry 3. Setting week to 0.
# Missing description for project To the Quantum Future, timeline entry 3. Setting description to ''.
# Missing week information for project To the Quantum Future, timeline entry 4. Setting week to 0.
# Missing description for project To the Quantum Future, timeline entry 4. Setting description to ''.
# Missing week information for project To the Quantum Future, timeline entry 5. Setting week to 0.
# Missing description for project To the Quantum Future, timeline entry 5. Setting description to ''.
# Missing week information for project To the Quantum Future, timeline entry 6. Setting week to 0.
# Missing description for project To the Quantum Future, timeline entry 6. Setting description to ''.
# Missing week information for project To the Quantum Future, timeline entry 7. Setting week to 0.
# Missing description for project To the Quantum Future, timeline entry 7. Setting description to ''.
# Missing week information for project To the Quantum Future, timeline entry 8. Setting week to 0.
# Missing description for project To the Quantum Future, timeline entry 8. Setting description to ''.
# Missing week information for project Street Fighter II - Reinforcement Learning, timeline entry 0. Setting week to 0.
# Missing description for project Street Fighter II - Reinforcement Learning, timeline entry 0. Setting description to ''.
# Missing week information for project Street Fighter II - Reinforcement Learning, timeline entry 1. Setting week to 0.
# Missing description for project Street Fighter II - Reinforcement Learning, timeline entry 1. Setting description to ''.
# Missing week information for project Street Fighter II - Reinforcement Learning, timeline entry 2. Setting week to 0.
# Missing description for project Street Fighter II - Reinforcement Learning, timeline entry 2. Setting description to ''.
# Missing week information for project Street Fighter II - Reinforcement Learning, timeline entry 3. Setting week to 0.
# Missing description for project Street Fighter II - Reinforcement Learning, timeline entry 3. Setting description to ''.
# Missing week information for project Street Fighter II - Reinforcement Learning, timeline entry 4. Setting week to 0.
# Missing description for project Street Fighter II - Reinforcement Learning, timeline entry 4. Setting description to ''.
# Missing week information for project Combinatorial Computing, timeline entry 0. Setting week to 0.
# Missing description for project Combinatorial Computing, timeline entry 0. Setting description to ''.
# Missing week information for project Combinatorial Computing, timeline entry 1. Setting week to 0.
# Missing description for project Combinatorial Computing, timeline entry 1. Setting description to ''.
# Missing week information for project Combinatorial Computing, timeline entry 2. Setting week to 0.
# Missing description for project Combinatorial Computing, timeline entry 2. Setting description to ''.
# Missing week information for project Combinatorial Computing, timeline entry 3. Setting week to 0.
# Missing description for project Combinatorial Computing, timeline entry 3. Setting description to ''.
# Missing week information for project Combinatorial Computing, timeline entry 4. Setting week to 0.
# Missing description for project Combinatorial Computing, timeline entry 4. Setting description to ''.
# Missing week information for project Combinatorial Computing, timeline entry 5. Setting week to 0.
# Missing description for project Combinatorial Computing, timeline entry 5. Setting description to ''.
# Missing week information for project Combinatorial Computing, timeline entry 6. Setting week to 0.
# Missing description for project Combinatorial Computing, timeline entry 6. Setting description to ''.
# Missing week information for project Combinatorial Computing, timeline entry 7. Setting week to 0.
# Missing description for project Combinatorial Computing, timeline entry 7. Setting description to ''.
# Missing week information for project Navigating the Waters of AI, timeline entry 0. Setting week to 0.
# Missing description for project Navigating the Waters of AI, timeline entry 0. Setting description to ''.
# Missing week information for project Navigating the Waters of AI, timeline entry 1. Setting week to 0.
# Missing description for project Navigating the Waters of AI, timeline entry 1. Setting description to ''.
# Missing week information for project Navigating the Waters of AI, timeline entry 2. Setting week to 0.
# Missing description for project Navigating the Waters of AI, timeline entry 2. Setting description to ''.
# Missing week information for project Navigating the Waters of AI, timeline entry 3. Setting week to 0.
# Missing description for project Navigating the Waters of AI, timeline entry 3. Setting description to ''.
# Missing week information for project Autonomous Driving Vehicle, timeline entry 0. Setting week to 0.
# Missing description for project Autonomous Driving Vehicle, timeline entry 0. Setting description to ''.
# Missing week information for project Autonomous Driving Vehicle, timeline entry 1. Setting week to 0.
# Missing description for project Autonomous Driving Vehicle, timeline entry 1. Setting description to ''.
# Missing week information for project Autonomous Driving Vehicle, timeline entry 2. Setting week to 0.
# Missing description for project Autonomous Driving Vehicle, timeline entry 2. Setting description to ''.
# Missing week information for project Autonomous Driving Vehicle, timeline entry 3. Setting week to 0.
# Missing description for project Autonomous Driving Vehicle, timeline entry 3. Setting description to ''.
# Missing week information for project Autonomous Driving Vehicle, timeline entry 4. Setting week to 0.
# Missing description for project Autonomous Driving Vehicle, timeline entry 4. Setting description to ''.
# Missing week information for project Autonomous Driving Vehicle, timeline entry 5. Setting week to 0.
# Missing description for project Autonomous Driving Vehicle, timeline entry 5. Setting description to ''.
# Missing week information for project Author Identification through Stylometric Analysis, timeline entry 0. Setting week to 0.
# Missing description for project Author Identification through Stylometric Analysis, timeline entry 0. Setting description to ''.
# Missing week information for project Author Identification through Stylometric Analysis, timeline entry 1. Setting week to 0.
# Missing description for project Author Identification through Stylometric Analysis, timeline entry 1. Setting description to ''.
# Missing week information for project Author Identification through Stylometric Analysis, timeline entry 2. Setting week to 0.
# Missing description for project Author Identification through Stylometric Analysis, timeline entry 2. Setting description to ''.
# Missing week information for project Author Identification through Stylometric Analysis, timeline entry 3. Setting week to 0.
# Missing description for project Author Identification through Stylometric Analysis, timeline entry 3. Setting description to ''.
# Missing week information for project Author Identification through Stylometric Analysis, timeline entry 4. Setting week to 0.
# Missing description for project Author Identification through Stylometric Analysis, timeline entry 4. Setting description to ''.
# Missing week information for project Breakout Genius - Using RL to Build an AI Game Master, timeline entry 0. Setting week to 0.
# Missing description for project Breakout Genius - Using RL to Build an AI Game Master, timeline entry 0. Setting description to ''.
# Missing week information for project Breakout Genius - Using RL to Build an AI Game Master, timeline entry 1. Setting week to 0.
# Missing description for project Breakout Genius - Using RL to Build an AI Game Master, timeline entry 1. Setting description to ''.
# Missing week information for project Breakout Genius - Using RL to Build an AI Game Master, timeline entry 2. Setting week to 0.
# Missing description for project Breakout Genius - Using RL to Build an AI Game Master, timeline entry 2. Setting description to ''.
# Missing week information for project Breakout Genius - Using RL to Build an AI Game Master, timeline entry 3. Setting week to 0.
# Missing description for project Breakout Genius - Using RL to Build an AI Game Master, timeline entry 3. Setting description to ''.
# Missing week information for project Image Captioning, timeline entry 0. Setting week to 0.
# Missing description for project Image Captioning, timeline entry 0. Setting description to ''.
# Missing week information for project Image Captioning, timeline entry 1. Setting week to 0.
# Missing description for project Image Captioning, timeline entry 1. Setting description to ''.
# Missing week information for project Image Captioning, timeline entry 2. Setting week to 0.
# Missing description for project Image Captioning, timeline entry 2. Setting description to ''.
# Missing week information for project Image Captioning, timeline entry 3. Setting week to 0.
# Missing description for project Image Captioning, timeline entry 3. Setting description to ''.
# Missing week information for project Image Captioning, timeline entry 4. Setting week to 0.
# Missing description for project Image Captioning, timeline entry 4. Setting description to ''.
# Missing week information for project Image Captioning, timeline entry 5. Setting week to 0.
# Missing description for project Image Captioning, timeline entry 5. Setting description to ''.
# Missing week information for project Cricbuzz, timeline entry 0. Setting week to 0.
# Missing description for project Cricbuzz, timeline entry 0. Setting description to ''.
# Missing week information for project Cricbuzz, timeline entry 1. Setting week to 0.
# Missing description for project Cricbuzz, timeline entry 1. Setting description to ''.
# Missing week information for project Cricbuzz, timeline entry 2. Setting week to 0.
# Missing description for project Cricbuzz, timeline entry 2. Setting description to ''.
# Missing week information for project Cricbuzz, timeline entry 3. Setting week to 0.
# Missing description for project Cricbuzz, timeline entry 3. Setting description to ''.
# Missing week information for project Cricbuzz, timeline entry 4. Setting week to 0.
# Missing description for project Cricbuzz, timeline entry 4. Setting description to ''.
# Missing week information for project Cricbuzz, timeline entry 5. Setting week to 0.
# Missing description for project Cricbuzz, timeline entry 5. Setting description to ''.
# Missing week information for project Competitive Programming (CP), timeline entry 0. Setting week to 0.
# Missing description for project Competitive Programming (CP), timeline entry 0. Setting description to ''.
# Missing week information for project Competitive Programming (CP), timeline entry 1. Setting week to 0.
# Missing description for project Competitive Programming (CP), timeline entry 1. Setting description to ''.
# Missing week information for project Competitive Programming (CP), timeline entry 2. Setting week to 0.
# Missing description for project Competitive Programming (CP), timeline entry 2. Setting description to ''.
# Missing week information for project Competitive Programming (CP), timeline entry 3. Setting week to 0.
# Missing description for project Competitive Programming (CP), timeline entry 3. Setting description to ''.
# Missing week information for project Competitive Programming (CP), timeline entry 4. Setting week to 0.
# Missing description for project Competitive Programming (CP), timeline entry 4. Setting description to ''.
# Missing week information for project Competitive Programming (CP), timeline entry 5. Setting week to 0.
# Missing description for project Competitive Programming (CP), timeline entry 5. Setting description to ''.
# Missing week information for project Economics meets Machine Learning, timeline entry 0. Setting week to 0.
# Missing description for project Economics meets Machine Learning, timeline entry 0. Setting description to ''.
# Missing week information for project Economics meets Machine Learning, timeline entry 1. Setting week to 0.
# Missing description for project Economics meets Machine Learning, timeline entry 1. Setting description to ''.
# Missing week information for project Economics meets Machine Learning, timeline entry 2. Setting week to 0.
# Missing description for project Economics meets Machine Learning, timeline entry 2. Setting description to ''.
# Missing week information for project Economics meets Machine Learning, timeline entry 3. Setting week to 0.
# Missing description for project Economics meets Machine Learning, timeline entry 3. Setting description to ''.
# Missing week information for project Economics meets Machine Learning, timeline entry 4. Setting week to 0.
# Missing description for project Economics meets Machine Learning, timeline entry 4. Setting description to ''.
# Missing week information for project Economics meets Machine Learning, timeline entry 5. Setting week to 0.
# Missing description for project Economics meets Machine Learning, timeline entry 5. Setting description to ''.
# Missing week information for project SynerG Lab, CSE Department - Webpage, timeline entry 0. Setting week to 0.
# Missing description for project SynerG Lab, CSE Department - Webpage, timeline entry 0. Setting description to ''.
# Missing week information for project SynerG Lab, CSE Department - Webpage, timeline entry 1. Setting week to 0.
# Missing description for project SynerG Lab, CSE Department - Webpage, timeline entry 1. Setting description to ''.
# Missing week information for project SynerG Lab, CSE Department - Webpage, timeline entry 2. Setting week to 0.
# Missing description for project SynerG Lab, CSE Department - Webpage, timeline entry 2. Setting description to ''.
# Missing week information for project SynerG Lab, CSE Department - Webpage, timeline entry 3. Setting week to 0.
# Missing description for project SynerG Lab, CSE Department - Webpage, timeline entry 3. Setting description to ''.
# Missing week information for project Computer vision for driverless vehicles, timeline entry 0. Setting week to 0.
# Missing description for project Computer vision for driverless vehicles, timeline entry 0. Setting description to ''.
# Missing week information for project Computer vision for driverless vehicles, timeline entry 1. Setting week to 0.
# Missing description for project Computer vision for driverless vehicles, timeline entry 1. Setting description to ''.
# Missing week information for project Computer vision for driverless vehicles, timeline entry 2. Setting week to 0.
# Missing description for project Computer vision for driverless vehicles, timeline entry 2. Setting description to ''.
# Missing week information for project Computer vision for driverless vehicles, timeline entry 3. Setting week to 0.
# Missing description for project Computer vision for driverless vehicles, timeline entry 3. Setting description to ''.
# Missing week information for project Computer vision for driverless vehicles, timeline entry 4. Setting week to 0.
# Missing description for project Computer vision for driverless vehicles, timeline entry 4. Setting description to ''.
# Missing week information for project AudioHive A Social Audio App, timeline entry 0. Setting week to 0.
# Missing description for project AudioHive A Social Audio App, timeline entry 0. Setting description to ''.
# Missing week information for project AudioHive A Social Audio App, timeline entry 1. Setting week to 0.
# Missing description for project AudioHive A Social Audio App, timeline entry 1. Setting description to ''.
# Missing week information for project AudioHive A Social Audio App, timeline entry 2. Setting week to 0.
# Missing description for project AudioHive A Social Audio App, timeline entry 2. Setting description to ''.
# Missing week information for project AudioHive A Social Audio App, timeline entry 3. Setting week to 0.
# Missing description for project AudioHive A Social Audio App, timeline entry 3. Setting description to ''.
# Missing week information for project AudioHive A Social Audio App, timeline entry 4. Setting week to 0.
# Missing description for project AudioHive A Social Audio App, timeline entry 4. Setting description to ''.
# Missing week information for project AudioHive A Social Audio App, timeline entry 5. Setting week to 0.
# Missing description for project AudioHive A Social Audio App, timeline entry 5. Setting description to ''.
# Missing week information for project AudioHive A Social Audio App, timeline entry 6. Setting week to 0.
# Missing description for project AudioHive A Social Audio App, timeline entry 6. Setting description to ''.
# Missing week information for project Learning the Latent structure in LLMs, timeline entry 0. Setting week to 0.
# Missing description for project Learning the Latent structure in LLMs, timeline entry 0. Setting description to ''.
# Missing week information for project Learning the Latent structure in LLMs, timeline entry 1. Setting week to 0.
# Missing description for project Learning the Latent structure in LLMs, timeline entry 1. Setting description to ''.
# Missing week information for project Learning the Latent structure in LLMs, timeline entry 2. Setting week to 0.
# Missing description for project Learning the Latent structure in LLMs, timeline entry 2. Setting description to ''.
# Missing week information for project Learning the Latent structure in LLMs, timeline entry 3. Setting week to 0.
# Missing description for project Learning the Latent structure in LLMs, timeline entry 3. Setting description to ''.
# Missing week information for project Learning the Latent structure in LLMs, timeline entry 4. Setting week to 0.
# Missing description for project Learning the Latent structure in LLMs, timeline entry 4. Setting description to ''.
# Missing week information for project EdConnect, timeline entry 0. Setting week to 0.
# Missing description for project EdConnect, timeline entry 0. Setting description to ''.
# Missing week information for project EdConnect, timeline entry 1. Setting week to 0.
# Missing description for project EdConnect, timeline entry 1. Setting description to ''.
# Missing week information for project EdConnect, timeline entry 2. Setting week to 0.
# Missing description for project EdConnect, timeline entry 2. Setting description to ''.
# Missing week information for project EdConnect, timeline entry 3. Setting week to 0.
# Missing description for project EdConnect, timeline entry 3. Setting description to ''.
# Missing week information for project EdConnect, timeline entry 4. Setting week to 0.
# Missing description for project EdConnect, timeline entry 4. Setting description to ''.
# Missing week information for project EdConnect, timeline entry 5. Setting week to 0.
# Missing description for project EdConnect, timeline entry 5. Setting description to ''.
# Missing week information for project NFTs Where Art and Tech Converge, timeline entry 0. Setting week to 0.
# ...
# Missing week information for project Hands on Reinforcement, timeline entry 0. Setting week to 0.
# Missing description for project Hands on Reinforcement, timeline entry 0. Setting description to ''.
# Missing week information for project Hands on Reinforcement, timeline entry 1. Setting week to 0.
# Missing description for project Hands on Reinforcement, timeline entry 1. Setting description to ''.
# Missing week information for project Hands on Reinforcement, timeline entry 2. Setting week to 0.
# Missing description for project Hands on Reinforcement, timeline entry 2. Setting description to ''.
# Missing week information for project Hands on Reinforcement, timeline entry 3. Setting week to 0.
# Missing description for project Hands on Reinforcement, timeline entry 3. Setting description to ''.
# Missing week information for project Hands on Reinforcement, timeline entry 4. Setting week to 0.
# Missing description for project Hands on Reinforcement, timeline entry 4. Setting description to ''.
# Missing week information for project Hands on Reinforcement, timeline entry 5. Setting week to 0.
# Missing description for project Hands on Reinforcement, timeline entry 5. Setting description to ''.
# Missing week information for project Hands on Reinforcement, timeline entry 6. Setting week to 0.
# Missing description for project Hands on Reinforcement, timeline entry 6. Setting description to ''.
# Missing week information for project RegExamaton, timeline entry 0. Setting week to 0.
# Missing description for project RegExamaton, timeline entry 0. Setting description to ''.
# Missing week information for project RegExamaton, timeline entry 1. Setting week to 0.
# Missing description for project RegExamaton, timeline entry 1. Setting description to ''.
# Missing week information for project RegExamaton, timeline entry 2. Setting week to 0.
# Missing description for project RegExamaton, timeline entry 2. Setting description to ''.
# Missing week information for project RegExamaton, timeline entry 3. Setting week to 0.
# Missing description for project RegExamaton, timeline entry 3. Setting description to ''.
# Missing week information for project RegExamaton, timeline entry 4. Setting week to 0.
# Missing description for project RegExamaton, timeline entry 4. Setting description to ''.
# Missing week information for project RegExamaton, timeline entry 5. Setting week to 0.
# Missing description for project RegExamaton, timeline entry 5. Setting description to ''.
# Missing week information for project Institute OnChain Voting System with ZKPs, timeline entry 0. Setting week to 0.
# Missing description for project Institute OnChain Voting System with ZKPs, timeline entry 0. Setting description to ''.
# Missing week information for project Institute OnChain Voting System with ZKPs, timeline entry 1. Setting week to 0.
# Missing description for project Institute OnChain Voting System with ZKPs, timeline entry 1. Setting description to ''.
# Missing week information for project Institute OnChain Voting System with ZKPs, timeline entry 2. Setting week to 0.
# Missing description for project Institute OnChain Voting System with ZKPs, timeline entry 2. Setting description to ''.
# Missing week information for project Institute OnChain Voting System with ZKPs, timeline entry 3. Setting week to 0.
# Missing description for project Institute OnChain Voting System with ZKPs, timeline entry 3. Setting description to ''.
# Missing week information for project Institute OnChain Voting System with ZKPs, timeline entry 4. Setting week to 0.
# Missing description for project Institute OnChain Voting System with ZKPs, timeline entry 4. Setting description to ''.
# Missing week information for project Institute OnChain Voting System with ZKPs, timeline entry 5. Setting week to 0.
# Missing description for project Institute OnChain Voting System with ZKPs, timeline entry 5. Setting description to ''.
# Missing week information for project Using Deep RL and NLP to allocate stocks in portfolio, timeline entry 0. Setting week to 0.
# Missing description for project Using Deep RL and NLP to allocate stocks in portfolio, timeline entry 0. Setting description to ''.
# Missing week information for project Using Deep RL and NLP to allocate stocks in portfolio, timeline entry 1. Setting week to 0.
# Missing description for project Using Deep RL and NLP to allocate stocks in portfolio, timeline entry 1. Setting description to ''.
# Missing week information for project Using Deep RL and NLP to allocate stocks in portfolio, timeline entry 2. Setting week to 0.
# Missing description for project Using Deep RL and NLP to allocate stocks in portfolio, timeline entry 2. Setting description to ''.
# Missing week information for project Using Deep RL and NLP to allocate stocks in portfolio, timeline entry 3. Setting week to 0.
# Missing description for project Using Deep RL and NLP to allocate stocks in portfolio, timeline entry 3. Setting description to ''.
# Missing week information for project Using Deep RL and NLP to allocate stocks in portfolio, timeline entry 4. Setting week to 0.
# Missing description for project Using Deep RL and NLP to allocate stocks in portfolio, timeline entry 4. Setting description to ''.
# Missing week information for project Using Deep RL and NLP to allocate stocks in portfolio, timeline entry 5. Setting week to 0.
# Missing description for project Using Deep RL and NLP to allocate stocks in portfolio, timeline entry 5. Setting description to ''.
# Missing week information for project Blockchain Development- It's not that difficult!, timeline entry 0. Setting week to 0.
# Missing description for project Blockchain Development- It's not that difficult!, timeline entry 0. Setting description to ''.
# Missing week information for project Blockchain Development- It's not that difficult!, timeline entry 1. Setting week to 0.
# Missing description for project Blockchain Development- It's not that difficult!, timeline entry 1. Setting description to ''.
# Missing week information for project Blockchain Development- It's not that difficult!, timeline entry 2. Setting week to 0.
# Missing description for project Blockchain Development- It's not that difficult!, timeline entry 2. Setting description to ''.
# Missing week information for project Blockchain Development- It's not that difficult!, timeline entry 3. Setting week to 0.
# Missing description for project Blockchain Development- It's not that difficult!, timeline entry 3. Setting description to ''.
# Missing week information for project Blockchain Development- It's not that difficult!, timeline entry 4. Setting week to 0.
# Missing description for project Blockchain Development- It's not that difficult!, timeline entry 4. Setting description to ''.
# Missing week information for project Blockchain Development- It's not that difficult!, timeline entry 5. Setting week to 0.
# Missing description for project Blockchain Development- It's not that difficult!, timeline entry 5. Setting description to ''.
# Missing week information for project Blockchain Development- It's not that difficult!, timeline entry 6. Setting week to 0.
# Missing description for project Blockchain Development- It's not that difficult!, timeline entry 6. Setting description to ''.
# Missing week information for project Blockchain Development- It's not that difficult!, timeline entry 7. Setting week to 0.
# Missing description for project Blockchain Development- It's not that difficult!, timeline entry 7. Setting description to ''.
# Missing week information for project Light field imaging and Dual Attention Networks, timeline entry 0. Setting week to 0.
# Missing description for project Light field imaging and Dual Attention Networks, timeline entry 0. Setting description to ''.
# Missing week information for project Light field imaging and Dual Attention Networks, timeline entry 1. Setting week to 0.
# Missing description for project Light field imaging and Dual Attention Networks, timeline entry 1. Setting description to ''.
# Missing week information for project Light field imaging and Dual Attention Networks, timeline entry 2. Setting week to 0.
# Missing description for project Light field imaging and Dual Attention Networks, timeline entry 2. Setting description to ''.
# Missing week information for project Light field imaging and Dual Attention Networks, timeline entry 3. Setting week to 0.
# Missing description for project Light field imaging and Dual Attention Networks, timeline entry 3. Setting description to ''.
# Missing week information for project Light field imaging and Dual Attention Networks, timeline entry 4. Setting week to 0.
# Missing description for project Light field imaging and Dual Attention Networks, timeline entry 4. Setting description to ''.
# Missing week information for project Light field imaging and Dual Attention Networks, timeline entry 5. Setting week to 0.
# Missing description for project Light field imaging and Dual Attention Networks, timeline entry 5. Setting description to ''.
# Missing week information for project Stable Diffusion, timeline entry 0. Setting week to 0.
# Missing description for project Stable Diffusion, timeline entry 0. Setting description to ''.
# Missing week information for project Stable Diffusion, timeline entry 1. Setting week to 0.
# Missing description for project Stable Diffusion, timeline entry 1. Setting description to ''.
# Missing week information for project Stable Diffusion, timeline entry 2. Setting week to 0.
# Missing description for project Stable Diffusion, timeline entry 2. Setting description to ''.
# Missing week information for project Stable Diffusion, timeline entry 3. Setting week to 0.
# Missing description for project Stable Diffusion, timeline entry 3. Setting description to ''.
# Missing week information for project Stable Diffusion, timeline entry 4. Setting week to 0.
# Missing description for project Stable Diffusion, timeline entry 4. Setting description to ''.
# Missing week information for project Stable Diffusion, timeline entry 5. Setting week to 0.
# Missing description for project Stable Diffusion, timeline entry 5. Setting description to ''.
# Missing week information for project Stable Diffusion, timeline entry 6. Setting week to 0.
# Missing description for project Stable Diffusion, timeline entry 6. Setting description to ''.
# Missing week information for project Stable Diffusion, timeline entry 7. Setting week to 0.
# Missing description for project Stable Diffusion, timeline entry 7. Setting description to ''.
# Missing week information for project Stable Diffusion, timeline entry 8. Setting week to 0.
# Missing description for project Stable Diffusion, timeline entry 8. Setting description to ''.
# Missing week information for project FlappeRL, timeline entry 0. Setting week to 0.
# Missing description for project FlappeRL, timeline entry 0. Setting description to ''.
# Missing week information for project FlappeRL, timeline entry 1. Setting week to 0.
# Missing description for project FlappeRL, timeline entry 1. Setting description to ''.
# Missing week information for project FlappeRL, timeline entry 2. Setting week to 0.
# Missing description for project FlappeRL, timeline entry 2. Setting description to ''.
# Missing week information for project FlappeRL, timeline entry 3. Setting week to 0.
# Missing description for project FlappeRL, timeline entry 3. Setting description to ''.
# Missing week information for project FlappeRL, timeline entry 4. Setting week to 0.
# Missing description for project FlappeRL, timeline entry 4. Setting description to ''.
# Missing week information for project Hands-on Computational Physics, timeline entry 0. Setting week to 0.
# Missing description for project Hands-on Computational Physics, timeline entry 0. Setting description to ''.
# Missing week information for project Hands-on Computational Physics, timeline entry 1. Setting week to 0.
# Missing description for project Hands-on Computational Physics, timeline entry 1. Setting description to ''.
# Missing week information for project Hands-on Computational Physics, timeline entry 2. Setting week to 0.
# Missing description for project Hands-on Computational Physics, timeline entry 2. Setting description to ''.
# Missing week information for project Hands-on Computational Physics, timeline entry 3. Setting week to 0.
# Missing description for project Hands-on Computational Physics, timeline entry 3. Setting description to ''.
# Missing week information for project Image Colorization, timeline entry 0. Setting week to 0.
# Missing description for project Image Colorization, timeline entry 0. Setting description to ''.
# Missing week information for project Image Colorization, timeline entry 1. Setting week to 0.
# Missing description for project Image Colorization, timeline entry 1. Setting description to ''.
# Missing week information for project Image Colorization, timeline entry 2. Setting week to 0.
# Missing description for project Image Colorization, timeline entry 2. Setting description to ''.
# Missing week information for project Image Colorization, timeline entry 3. Setting week to 0.
# Missing description for project Image Colorization, timeline entry 3. Setting description to ''.
# Missing week information for project Image Colorization, timeline entry 4. Setting week to 0.
# Missing description for project Image Colorization, timeline entry 4. Setting description to ''.
# Missing week information for project PaperPal, timeline entry 0. Setting week to 0.
# Missing description for project PaperPal, timeline entry 0. Setting description to ''.
# Missing week information for project PaperPal, timeline entry 1. Setting week to 0.
# Missing description for project PaperPal, timeline entry 1. Setting description to ''.
# Missing week information for project PaperPal, timeline entry 2. Setting week to 0.
# Missing description for project PaperPal, timeline entry 2. Setting description to ''.
# Missing week information for project PaperPal, timeline entry 3. Setting week to 0.
# Missing description for project PaperPal, timeline entry 3. Setting description to ''.
# Missing week information for project PaperPal, timeline entry 4. Setting week to 0.
# Missing description for project PaperPal, timeline entry 4. Setting description to ''.
# Missing week information for project PaperPal, timeline entry 5. Setting week to 0.
# Missing description for project PaperPal, timeline entry 5. Setting description to ''.
# Missing week information for project PaperPal, timeline entry 6. Setting week to 0.
# Missing description for project PaperPal, timeline entry 6. Setting description to ''.
# Missing week information for project PaperPal, timeline entry 7. Setting week to 0.
# Missing description for project PaperPal, timeline entry 7. Setting description to ''.
# Missing week information for project JobFinderX, timeline entry 0. Setting week to 0.
# Missing description for project JobFinderX, timeline entry 0. Setting description to ''.
# Missing week information for project JobFinderX, timeline entry 1. Setting week to 0.
# Missing description for project JobFinderX, timeline entry 1. Setting description to ''.
# Missing week information for project JobFinderX, timeline entry 2. Setting week to 0.
# Missing description for project JobFinderX, timeline entry 2. Setting description to ''.
# Missing week information for project JobFinderX, timeline entry 3. Setting week to 0.
# Missing description for project JobFinderX, timeline entry 3. Setting description to ''.
# Missing week information for project JobFinderX, timeline entry 4. Setting week to 0.
# Missing description for project JobFinderX, timeline entry 4. Setting description to ''.
# Missing week information for project JobFinderX, timeline entry 5. Setting week to 0.
# Missing description for project JobFinderX, timeline entry 5. Setting description to ''.
# Missing week information for project JobFinderX, timeline entry 6. Setting week to 0.
# Missing description for project JobFinderX, timeline entry 6. Setting description to ''.

# %%
project_info_df.to_csv("project_info.csv", index=False)

# %%
project_info_df
# Out:
#                                       TEXT SUMMARIZATION WEB APP  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors              [kundeshwar vijay pundalik, ADRESH ALAGADE]
# timeline       [{'Week': 'Week 1-3', 'Work': 'EDA and Some ot...
# prerequisites  BASIC PYTHON , (HTML OR STREAMLIT) , BASIC KNO...
#
#                                          Competitive Programming  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                                         [Virendra Kabra]
# timeline       [{'Week': 'Week 1', 'Work': 'C++ STL Basics', ...
# prerequisites                                                N/A
#
#                                            Write yourself a Git!  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                                  [Abhijeet Prasad Bodas]
# timeline       [{'Week': 'Week 1', 'Work': 'Install a GNU/Lin...
# prerequisites                                                N/A
#
#                                          File Compression System  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                                      [Amritaansh Narain]
# timeline       [{'Week': 'Week 1&2', 'Work': 'Basic overview ...
# prerequisites  Assume you have basic understanding of C++ and...
#
#                                                           FAST-G  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors        [Ameya Vikram Singh, Prerak Contractor, Anish ...
# timeline       [{'Week': 'Week 1', 'Work': 'Basics of graphs ...
# prerequisites                                                N/A
#
#                     Developing Trading Strategy with Pine Script  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                               [Vivek Kumar, Rajik Kumar]
# timeline       [{'Week': 'Week 1-3', 'Work': 'Introduction to...
# prerequisites                                                N/A
#
#                     Real time Driver Drowsiness detection System  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                                            [Vedang Bale]
# timeline       [{'Week': 'Week 1', 'Work': 'Python Programmin...
# prerequisites                                                N/A
#
#                                           The Image Cartoonifier  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors               [Jaideep Chandra, Sridhar, Bhavani Sankar]
# timeline       [{'Week': 'Week 1', 'Work': 'Introduction to P...
# prerequisites                                                N/A
#
#                                     Speech to Speech Translation  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                                       [Swapnoneel Kayal]
# timeline       [{'Week': 'Week 1', 'Work': 'Brush up on / Pyt...
# prerequisites                                                N/A
#
#                       Competitive Programming - Newbie to Master  ...  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...  ...
# mentors                          [Parth Dwivedi, Kunal Kundwani]  ...
# timeline       [{'Week': 'Week 1', 'Work': 'Start out with ba...  ...
# prerequisites                                                N/A  ...
#
#                        Institute OnChain Voting System with ZKPs  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors           [Nikhil Tiwari, Ananya Khandelwal, Ishit Garg]
# timeline       [{'Week': 'Week 1', 'Work': 'Gain basic knowle...
# prerequisites                                                N/A
#
#               Using Deep RL and NLP to allocate stocks in portfolio  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                  [Nikhil Tiwari, Ishan Jain (200100073)]
# timeline       [{'Week': 'Week 1', 'Work': 'Read basics of de...
# prerequisites                                                N/A
#
#                 Blockchain Development- It's not that difficult!  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors        [Pragyesh Gupta, Dhruvkumar Patil (200100056),...
# timeline       [{'Week': 'Week 1', 'Work': ' Introduction to ...
# prerequisites                                                N/A
#
#                  Light field imaging and Dual Attention Networks  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                [Abeer Mishra, Shreyas Patil (200260052)]
# timeline       [{'Week': 'Week 1-2', 'Work': ' Basics of Mach...
# prerequisites                                                N/A
#
#                                                 Stable Diffusion  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors        [Shubham Hazra, Om Godage (21d100006), Kartik ...
# timeline       [{'Week': 'Week 1', 'Work': 'Basics of Regress...
# prerequisites                                                N/A
#
#                                                         FlappeRL  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                           [Kartik Gokhale, Hastyn Doshi]
# timeline       [{'Week': 'Week 1', 'Work': 'Catching up on Py...
# prerequisites                                                N/A
#
#                                   Hands-on Computational Physics  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors          [Kaustav Prasada, Varad Mahashabde (200260057)]
# timeline       [{'Week': 'Week 1-2', 'Work': '- Introduction ...
# prerequisites                                                N/A
#
#                                               Image Colorization  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors                                          [Valay Bundele]
# timeline       [{'Week': 'Week 1-2', 'Work': 'Read about the ...
# prerequisites                                                N/A
#
#                                                         PaperPal  \
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors            [Vishruth N, Abhinav Raghuvanshi (200040008)]
# timeline       [{'Week': 'Week 1', 'Work': 'Set up project re...
# prerequisites                                                N/A
#
#                                                       JobFinderX
# project_url    https://itc.gymkhana.iitb.ac.in/wncc/soc/proje...
# mentors        [Baggam Rakshan Tej (210070019), Pamba Ravindr...
# timeline       [{'Week': 'Week 1', 'Work': 'HTML, CSS', 'week...
# prerequisites                                                N/A
#
# [4 rows x 71 columns]
